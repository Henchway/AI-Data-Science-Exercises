# %%
import jsonpickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

with open("results_1000_2021-04-25.json", "r") as file:
    contents = file.read()
    unfrozen = jsonpickle.decode(contents)

df = pd.DataFrame(unfrozen)
cols = list(df.columns)

# %% [markdown]
# ## Group items
# Group items by depth (= how many steps were required to finish the puzzle), show the distribution of depths as chart

# %%
group = df.groupby(['depth'])
x_pos = [i for i, _ in enumerate(group)]
fig, ax = plt.subplots(figsize=(15,5))
plt.xticks(list(group.groups.keys()))
ax.bar(list(group.groups.keys()), list(group.size()))
plt.show()

# %% [markdown]
# ## Focus on a single constellation

# %%
x1 = np.array(df[0:25]['weights'].tolist())[:,0]
y1 = df[0:25]['expanded_nodes']
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[1].plot(x1,y1, "b--", label="Manhattan weight")
ax[1].set_xlabel("weight ratio")
ax[1].set_ylabel("expanded nodes")
ax[1].legend()

x2 = np.array(df[0:25]['weights'].tolist())[:,1]
y2 = df[0:25]['expanded_nodes']
ax[0].plot(x2,y2, "r--", label="Hamming weight")
ax[0].set_xlabel("weight ratio")
ax[0].set_ylabel("expanded nodes")
ax[0].legend()

plt.show()

# %% [markdown]
# ## Print constellation for all (average)
#
# Shows the average expanded nodes based on the weight

# %%
x1 = (np.array(df['weights'].tolist())[:,0])
y1 = (df['expanded_nodes'])

df['weight1'] = np.array(df['weights'].tolist())[:,0]
df['weight2'] = np.array(df['weights'].tolist())[:,1]
df.drop(['weights'], axis=1)

weight_group = df.groupby(['weight1', 'weight2'])

weight1_averages = []
weight2_averages = []
nodes_averages = []

for item in weight_group:
    weight1_averages.append(item[1]['weight1'].mean())
    weight2_averages.append(item[1]['weight2'].mean())
    nodes_averages.append(item[1]['expanded_nodes'].mean())

fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[1].plot(weight1_averages, nodes_averages, "b--", label="Manhattan weight") 
ax[1].set_xlabel("Weight ratio")
ax[1].set_ylabel("Average expanded nodes")
ax[1].legend()

ax[0].plot(weight2_averages, nodes_averages, "r--",label = "Hamming weight") 
ax[0].set_xlabel("Weight ratio")
ax[0].set_ylabel("Average expanded nodes")
ax[0].legend()

plt.show()

# %%
df = pd.DataFrame(unfrozen)

# %% [markdown]
# ## Min Nodes

# %%
min_value = group[['expanded_nodes']].min()
min_value
# Out:
#        expanded_nodes
# depth
# 9                  26
# 11                 36
# 12                 40
# 13                 42
# 14                 43
# 15                 73
# 16                 47
# 17                 96
# 18                 89
# 19                139
# 20                162
# 21                266
# 22                415
# 23                472
# 24                651
# 25               1203
# 26               1667
# 27               3815
# 28               5586
# 29              11776
# 30              11628

# %% [markdown]
# ## Max Nodes

# %%
min_value = group[['expanded_nodes']].max()
min_value
# Out:
#        expanded_nodes
# depth
# 9                  77
# 11                 98
# 12                179
# 13                175
# 14                327
# 15                538
# 16                817
# 17               1198
# 18               1808
# 19               2387
# 20               4641
# 21               5990
# 22               7086
# 23              11375
# 24              13657
# 25              20986
# 26              27547
# 27              41518
# 28              42300
# 29              43594
# 30              60294

# %% [markdown]
# ## Mean Nodes

# %%
mean_value = group[['expanded_nodes']].mean()
print(mean_value)
# Out:
#        expanded_nodes
# depth
# 9           44.880000
# 11          57.560000
# 12          95.940000
# 13          98.733333
# 14         134.240000
# 15         244.566154
# 16         306.615491
# 17         494.749677
# 18         662.327498
# 19         909.276662
# 20        1294.055729
# 21        1955.036852
# 22        2524.299184
# 23        4170.385070
# 24        5053.798514
# 25        7606.193623
# 26       10898.602453
# 27       15967.380303
# 28       19524.091440
# 29       27324.900000
# 30       37836.487179

# %% [markdown]
# ## Best weights bast on the least nodes per depth

# %%
min_nodes = df.loc[group['expanded_nodes'].idxmin()]
min_nodes
# Out:
#                              array                     weights  \
# 5459   (4, 7, 2, 1, 6, 5, 3, 0, 8)  [0.8199999999999998, 0.18]
# 5084   (1, 2, 5, 3, 6, 7, 4, 0, 8)  [0.8199999999999998, 0.18]
# 9360   (1, 5, 4, 6, 3, 7, 0, 8, 2)   [0.7999999999999998, 0.2]
# 10632  (4, 5, 3, 0, 7, 2, 1, 6, 8)  [0.8599999999999999, 0.14]
# 9059   (3, 2, 8, 5, 1, 7, 0, 4, 6)  [0.8199999999999998, 0.18]
# 6609   (4, 0, 3, 7, 8, 1, 6, 5, 2)  [0.8199999999999998, 0.18]
# 9407   (0, 5, 8, 2, 4, 7, 1, 3, 6)  [0.8599999999999999, 0.14]
# 12000  (1, 5, 7, 3, 8, 0, 4, 2, 6)                  [1.0, 0.0]
# 23531  (5, 7, 4, 1, 8, 6, 3, 2, 0)  [0.8799999999999999, 0.12]
# 6433   (1, 8, 4, 0, 6, 7, 5, 2, 3)  [0.8399999999999999, 0.16]
# 24100  (0, 6, 3, 8, 7, 2, 1, 5, 4)                  [1.0, 0.0]
# 24250  (4, 0, 6, 8, 7, 2, 1, 5, 3)                  [1.0, 0.0]
# 15308  (8, 4, 3, 5, 6, 1, 0, 2, 7)  [0.8399999999999999, 0.16]
# 7483   (8, 4, 7, 1, 6, 0, 5, 2, 3)  [0.8399999999999999, 0.16]
# 14400  (7, 5, 0, 2, 8, 6, 4, 1, 3)                  [1.0, 0.0]
# 5400   (6, 7, 8, 5, 4, 0, 1, 2, 3)                  [1.0, 0.0]
# 2025   (5, 7, 4, 8, 6, 3, 2, 1, 0)                  [1.0, 0.0]
# 1350   (4, 7, 6, 5, 2, 3, 8, 0, 1)                  [1.0, 0.0]
# 4107   (0, 7, 3, 8, 5, 6, 2, 1, 4)  [0.8599999999999999, 0.14]
# 14200  (6, 7, 8, 5, 4, 1, 2, 0, 3)                  [1.0, 0.0]
# 23634  (7, 8, 6, 5, 1, 3, 2, 4, 0)  [0.8199999999999998, 0.18]
#
#        expanded_nodes  time_elapsed  depth
# 5459               26      0.006001      9
# 5084               36      0.000000     11
# 9360               40      0.010000     12
# 10632              42      0.000000     13
# 9059               43      0.011998     14
# 6609               73      0.015625     15
# 9407               47      0.012000     16
# 12000              96      0.015625     17
# 23531              89      0.024000     18
# 6433              139      0.031249     19
# 24100             162      0.046875     20
# 24250             266      0.062500     21
# 15308             415      0.140625     22
# 7483              472      0.156249     23
# 14400             651      0.187509     24
# 5400             1203      0.445000     25
# 2025             1667      0.696392     26
# 1350             3815      2.344002     27
# 4107             5586      4.462210     28
# 14200           11776     19.061259     29
# 23634           11628     11.104558     30

# %% [markdown]
# ## Shows the optimal weight
# Based on the average of the least nodes expanded over all depths

# %%
np.mean(min_nodes['weights'].tolist(), axis=0)
# Out:
# array([0.89904762, 0.10095238])

# %% [markdown]
# ## Best weights based on the weights with the least nodes of each example

# %%
example_group = df.groupby('array')
test = df.loc[example_group['expanded_nodes'].idxmin()]
np.mean(test['weights'].tolist(), axis=0)
# Out:
# array([0.89573574, 0.10426426])
